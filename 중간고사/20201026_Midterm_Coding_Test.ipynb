# %%
import numpy as np
import sklearn as sk
import pandas as pd

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Upload 'new_train.csv' and 'new_test.csv' files into the Colab environment.
#
# 0. Download 'new_train.csv' and 'new_test.csv' from HISNet to your computer.
# 1. Run the code in the next cell.
# 2. Click "Select File(파일 선택)" button.
# 3. Select the two file(s) to upload.

# %%
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-aa32c9c1-2e74-457a-87a4-d193a598f506" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aa32c9c1-2e74-457a-87a4-d193a598f506">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-4d74d6a55243> in <module>()
#       1 from google.colab import files
# ----> 2 uploaded = files.upload()
#       3 for fn in uploaded.keys():
#       4   print('User uploaded file "{name}" with length {length} bytes'.format(name=fn, length=len(uploaded[fn])))
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in upload()
#      62   result = _output.eval_js(
#      63       'google.colab._files._uploadFiles("{input_id}", "{output_id}")'.format(
# ---> 64           input_id=input_id, output_id=output_id))
#      65   files = _collections.defaultdict(_six.binary_type)
#      66   # Mapping from original filename to filename as saved locally.
#
# /usr/local/lib/python3.6/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result)
#      37   if ignore_result:
#      38     return
# ---> 39   return _message.read_reply_from_input(request_id)
#      40
#      41
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      99     reply = _read_next_input_message()
#     100     if reply == _NOT_READY or not isinstance(reply, dict):
# --> 101       time.sleep(0.025)
#     102       continue
#     103     if (reply.get('type') == 'colab_reply' and
#
# KeyboardInterrupt:

# %% [markdown]
# ### The following code displays the first few lines of the uploaded files.

# %%
print("ls")
# !ls
print("The content of 'new_train.csv':")
# !head 'new_train.csv'
print("The content of 'new_test.csv':")
# !head 'new_test.csv'
# Out:
# ls
# new_test.csv  new_train.csv  sample_data
# The content of 'new_train.csv':
# feat1,feat2,feat3,feat4,feat5,feat6,feat7,feat8,target
# 112.24,54.19,30,14.936,128.3,33.83333333,65.69,47.2,133.8
# 153,54.4,38,18.2,190.1,37.63333333,65.53,46.3,160.2
# 14.4,53.69,34,16.509,17.4,11.1,65.44,11.7,171.4
# 30.02,53.64,28,31.917,33.7,17.16666667,65.43,22.6,146.8
# 29.08,53.57,40,19.25,32.6,20.8,65.43,26.2,131
# 27.74,53.63,58,33.438,23.6,22.36666667,65.42,23.9,148
# 58.14,53.61,50,26.768,68,61.36666667,65.42,63.3,164.8
# 16.24,54.83,82,17.083,16.8,12.5,65.41,15.8,97
# 95.78,53.61,68,21.782,117.5,104.4666667,65.41,105.6,116.8
# The content of 'new_test.csv':
# feat1,feat2,feat3,feat4,feat5,feat6,feat7,feat8,target
# 77.7,57.37,54,66.085,66.1,51.23333333,57.95,60.6,689.4
# 30.2,54.26,86,35.99,31,26.96666667,61.7,27.7,353
# 71.78,53.78,54,57.934,50.7,49.46666667,62.19,49.5,541
# 1.34,53.82,56,61.359,1.5,1.633333333,61.64,1.1,660
# 24.82,56.33,38,29.375,24.4,28.33333333,60.33,23.7,163.4
# 20.36,56.51,74,16.635,21.3,22.1,60.44,20.4,134
# 20.18,58.63,86,16.641,22.5,20.13333333,58.57,21.8,134
# 46.2,55.48,38,32.25,47.1,44.7,59.35,44.1,333.8
# 61.6,58.4,30,36.696,61.7,48.2,57.16,59.9,388.8

# %% [markdown]
# # Problem 1: Load and observe data
#
# 1. Load the two csv files.
# 2. Display their count, mean, std, and the five-number summary (min, 25%, 50%, 75%, max).
# 3. Draw histogram of each column.

# %%
# training data
df_train = pd.read_csv("new_train.csv")
df_train = df_train.astype('float')

print(df_train.describe())

df_train.hist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-966629aac7d4> in <module>()
#       1 # training data
# ----> 2 df_train = pd.read_csv("new_train.csv")
#       3 df_train = df_train.astype('float')
#       4
#       5 print(df_train.describe())
#
# NameError: name 'pd' is not defined

# %%
# test data
df_test = pd.read_csv("new_test.csv")
df_test = df_test.astype('float')
print(df_test.describe())

df_test.hist()

# %% [markdown]
# # Problem 2: Prepare data
# 1. Convert the training and test data into numpy array.
# 2. Normalize the data by standardization and minmax normalization.

# %%
feature_columns = ['feat1', 'feat2', 'feat3', 'feat4', 'feat5', 'feat6', 'feat7', 'feat8']
target_column = 'target'

# %% [markdown]
# ### Convert the training and test data into numpy array.

# %%
# convert data into numpy array
X_train = df_train[feature_columns].to_numpy()
y_train = df_train['target'].to_numpy()

X_test = df_test[['feat1','feat2','feat3','feat4','feat5','feat6','feat7','feat8']].to_numpy()
y_test = df_test['target'].to_numpy()

# feat1         feat2  ...         feat8        target
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-4da9cd6855df> in <module>()
#       1 # convert data into numpy array
# ----> 2 X_train = df_train[feature_columns].to_numpy()
#       3 y_train = df_train['target'].to_numpy()
#       4
#       5 X_test = df_test[['feat1','feat2','feat3','feat4','feat5','feat6','feat7','feat8']].to_numpy()
#
# NameError: name 'df_train' is not defined

# %%
print("X_train.shape = ", X_train.shape, " y_train.shape = ", y_train.shape)
print("X_test.shape = ", X_test.shape, " y_test.shape = ", y_test.shape)

# %%
print(X_train[:5])
print(X_test[:5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-6ffd3ebf68ce> in <module>()
# ----> 1 print(X_train[:5])
#       2 print(X_test[:5])
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# ### Normalize data applying the following methods:
# 1. Standardization
# 2. Min-max normalization

# %%
# Standardization
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler().fit(X_train)
X_train_standard = scaler.transform(X_train)
X_test_standard = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-d71b3487b8a5> in <module>()
#       2 from sklearn.preprocessing import StandardScaler
#       3
# ----> 4 scaler = StandardScaler().fit(X_train)
#       5 X_train_standard = scaler.transform(X_train)
#       6 X_test_standard = scaler.transform(X_test)
#
# NameError: name 'X_train' is not defined

# %%
print(X_train_standard[:5])
print(X_test_standard[:5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-703041099027> in <module>()
# ----> 1 print(X_train_standard[:5])
#       2 print(X_test_standard[:5])
#
# NameError: name 'X_train_standard' is not defined

# %%
# min-max normalization
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler().fit(X_train)
X_train_minmax = scaler.transform(X_train)
X_test_minmax = scaler.transform(X_test)

# %%
print(X_train_minmax[:5])
print(X_test_minmax[:5])
# Out:
# [[0.14788454 0.17703863 0.2745098  0.06853009 0.19882043 0.02836402
#   1.         0.07730263]
#  [0.20160801 0.19957082 0.35294118 0.09104012 0.29473848 0.03155918
#   0.97982346 0.07582237]
#  [0.01892711 0.12339056 0.31372549 0.07937822 0.02669564 0.00924914
#   0.96847415 0.01891447]
#  [0.03951496 0.11802575 0.25490196 0.18563882 0.05199441 0.01435018
#   0.96721311 0.03684211]
#  [0.038276   0.11051502 0.37254902 0.0982814  0.05028713 0.0174052
#   0.96721311 0.04276316]]
# [[0.1023593  0.51824034 0.50980392 0.42127695 0.10228155 0.04299448
#   0.02395965 0.09934211]
#  [0.03975221 0.18454936 0.82352941 0.21372809 0.04780382 0.02259032
#   0.49684741 0.04523026]
#  [0.09455648 0.13304721 0.50980392 0.36506393 0.07837964 0.04150901
#   0.55863808 0.08108553]
#  [0.00171346 0.13733906 0.52941176 0.38868429 0.00201769 0.00128927
#   0.48928121 0.00148026]
#  [0.03266113 0.40665236 0.35294118 0.16810803 0.03756014 0.02373945
#   0.32408575 0.03865132]]

# %% [markdown]
# # Problem 3: Build a machine learning model that predicts the target values from the features.
#  * Do your best to achieve the highest performance on the test data using any methods or techniques learned from this course.
#  * However, DO NOT use ensemble methods.
#  * Referencing any code obtained from the Internet or other people will be regarded as cheating.

# %%
from sklearn.neural_network import MLPRegressor
mlp = MLPRegressor(activation = 'tanh', hidden_layer_sizes = (100,), max_iter=1000 ,random_state=42).fit(X_train_standard, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
layers = [(100,), (100,100), (100,100,100)]
for depth in layers:
  mlp = MLPRegressor(activation = 'tanh', hidden_layer_sizes = depth, max_iter=1000 ,random_state=42).fit(X_train_standard, y_train)
  print(mlp.score(X_test_standard, y_test))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:573: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# 0.6914672260820913
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:573: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# 0.7505617077842927
# -2.8931785821940847
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:573: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")

# %%
from sklearn.linear_model import Ridge
for a in [0.01, 0.1, 1, 10, 100]:
  ridge = Ridge(a).fit(X_train_minmax, y_train)
  print("alpha {:4} train score : {:5.5}".format(a, ridge.score(X_test_minmax, y_test)))

# %%
from sklearn.svm import SVC
C = [1/10, 1,10,100]
G = [0.01,0.1,1]
for cValue in C:
  for gamValue in G:
    svm = SVR(kernel='rbf', C=cValue, gamma=gamValue).fit(X_train_minmax, y_train)
    print("C = {:4} | gamma = {:4} train score : {:5.5}".format(cValue, gamValue, svm.score(X_test_minmax, y_test)))
# Out:
# C =  0.1 | gamma = 0.01 train score : -0.13199
# C =  0.1 | gamma =  0.1 train score : -0.12118
# C =  0.1 | gamma =    1 train score : -0.062346
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-113-ef29295c2b87> in <module>()
#       4 for cValue in C:
#       5   for gamValue in G:
# ----> 6     svm = SVR(kernel='rbf', C=cValue, gamma=gamValue).fit(X_train_minmax, y_train)
#       7     print("C = {:4} | gamma = {:4} train score : {:5.5}".format(cValue, gamValue, svm.score(X_test_minmax, y_test)))
#       8
#
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     197
#     198         seed = rnd.randint(np.iinfo('i').max)
# --> 199         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     200         # see comment on the other call to np.iinfo in this file
#     201
#
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     256                 cache_size=self.cache_size, coef0=self.coef0,
#     257                 gamma=self._gamma, epsilon=self.epsilon,
# --> 258                 max_iter=self.max_iter, random_seed=random_seed)
#     259
#     260         self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %%
from sklearn.neural_network import MLPRegressor
mlp = MLPRegressor(activation = 'tanh', hidden_layer_sizes = (100,100), max_iter=100 ,random_state=42).fit(X_train_standard, y_train)
print(mlp.score(X_test_standard, y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-715c3c7c1656> in <module>()
#       1 from sklearn.neural_network import MLPRegressor
# ----> 2 mlp = MLPRegressor(activation = 'tanh', hidden_layer_sizes = (100,100), max_iter=100 ,random_state=42).fit(X_train_standard, y_train)
#       3 print(mlp.score(X_test_standard, y_test))
#
# NameError: name 'X_train_standard' is not defined
